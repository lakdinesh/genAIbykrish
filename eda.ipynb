# %% [markdown]
# <a href="https://colab.research.google.com/github/lakdinesh/genAIbykrish/blob/main/eda.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from sklearn.preprocessing import LabelEncoder
from google.colab import drive
drive.mount('/content/drive',force_remount=True) #  Mount Google Drive to access files
df = '/content/drive/MyDrive/genaikrish/zomoto.csv'
# Out:
# Mounted at /content/drive

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_350/3289350417.py in <cell line: 0>()
# ----> 1 df.columns
#
# AttributeError: 'str' object has no attribute 'columns'
